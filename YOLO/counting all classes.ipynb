# %%
from ultralytics import YOLO
from ultralytics.solutions import object_counter
import cv2

# Load your model
model = YOLO("yolov8x.pt")

# Setup video capture
cap = cv2.VideoCapture("One minute highway.mp4")
assert cap.isOpened(), "Error reading video file"

# Define your classes to count here (e.g., 0 for person, 2 for car)
classes_to_count = [2, 7]

# Init Object Counter with your specific classes
counter = object_counter.ObjectCounter()
counter.set_args(view_img=True,
                 classes_names=model.names,
                 reg_pts = [(100, 230), (600, 230)],
                 draw_tracks=True)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        break
    tracks = model.track(im0, persist=True, show=False, classes=classes_to_count)

    # Start counting with specified classes
    im0 = counter.start_counting(im0, tracks)
        # Display
    #cv2.imshow("Count", im0)
    if cv2.waitKey(1) == ord('q'):  # press q to quit
        break
    # Here you can access the counts for each class
    #print(f"Counts: {counter.counts}")
q
cap.release()
cv2.destroyAllWindows()
# Out:
# Line Counter Initiated.
#
# 0: 384x640 4 cars, 68.2ms
# Speed: 2.6ms preprocess, 68.2ms inference, 1900.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 44.8ms
# Speed: 2.0ms preprocess, 44.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 40.0ms
# Speed: 3.0ms preprocess, 40.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 40.6ms
# Speed: 1.0ms preprocess, 40.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 40.1ms
# ...
